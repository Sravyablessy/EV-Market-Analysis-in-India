# %%
import pandas as pd

# %%
Maker_Place= pd.read_csv("/kaggle/input/ev-data/EV Maker by Place.csv")
print(Maker_Place)
print(" Finding is there any Null values")
Maker_Place.isnull().sum()
# Out:
#                        EV Maker        Place        State
# 0                   Tata Motors         Pune  Maharashtra
# 1             Mahindra Electric    Bengaluru    Karnataka
# 2                  Ather Energy    Bengaluru    Karnataka
# 3                 Hero Electric    New Delhi        Delhi
# 4                  Ola Electric  Krishnagiri   Tamil Nadu
# ..                          ...          ...          ...
# 57          YC Electric Vehicle        Delhi        Delhi
# 58  Dilli Electric Auto Pvt Ltd    New Delhi        Delhi
# 59           Electrotherm India    Ahmedabad      Gujarat
# 60        Lohia Auto Industries     Kashipur  Uttarakhand
# 61                 Euler Motors    New Delhi        Delhi
#
# [62 rows x 3 columns]
#  Finding is there any Null values
# EV Maker    0
# Place       0
# State       0
# dtype: int64

# %%
# Finding datatypes of the attributes
Maker_Place.dtypes
# Out:
# EV Maker    object
# Place       object
# State       object
# dtype: object

# %%
# The shape of the dataset (containg how many rows and columns)
Maker_Place.shape
# Out:
# (62, 3)

# %%
# Checking if there are any duplicate rows present in the data 
# and removing those rows from the dataset

print(Maker_Place.duplicated())
Makers= Maker_Place.drop_duplicates()
Makers
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60     True
# 61    False
# Length: 62, dtype: bool
#                        EV Maker        Place        State
# 0                   Tata Motors         Pune  Maharashtra
# 1             Mahindra Electric    Bengaluru    Karnataka
# 2                  Ather Energy    Bengaluru    Karnataka
# 3                 Hero Electric    New Delhi        Delhi
# 4                  Ola Electric  Krishnagiri   Tamil Nadu
# ..                          ...          ...          ...
# 56    Greaves Electric Mobility   Coimbatore   Tamil Nadu
# 57          YC Electric Vehicle        Delhi        Delhi
# 58  Dilli Electric Auto Pvt Ltd    New Delhi        Delhi
# 59           Electrotherm India    Ahmedabad      Gujarat
# 61                 Euler Motors    New Delhi        Delhi
#
# [61 rows x 3 columns]

# %%
# Basic statistical summaries

print(Makers.describe())
print("")
print("counting how many times the specific Place appears in data")
print(Makers['Place'].value_counts())
print("")
print("counting how many times the specific State appears")
print(Makers['State'].value_counts())
# Out:
#            EV Maker Place        State
# count            61    61           61
# unique           61    36           13
# top     Tata Motors  Pune  Maharashtra
# freq              1     7           15
#
# counting how many times the specific Place appears in data
# Place
# Pune             7
# Bengaluru        6
# Chennai          5
# New Delhi        3
# Mumbai           3
# Hyderabad        3
# Bhiwadi          2
# Kolkata          2
# Faridabad        2
# Coimbatore       2
# Akurdi           1
# Pithampur        1
# Jaipur           1
# Alwar            1
# Kashipur         1
# Morbi            1
# Gurugram         1
# Ahmednagar       1
# Delhi            1
# Ropar            1
# Rajkot           1
# Uttarpara        1
# Manesar          1
# Anantapur        1
# Chakan           1
# Aurangabad       1
# Thiruvallur      1
# Bhuj             1
# Dharuhera        1
# Baramati         1
# Sriperumbudur    1
# Gurgaon          1
# Halol            1
# Hosur            1
# ...

# %% [markdown]
# -- Maharastra is the state that occurs most of the times (15) in the dataset i.e., most of the EV Makers(Companies) are located in Maharastra.
#
# -- The unique Places appeared in the dataset are 36 out of 61, and Pune is the one which occurs most in the dataset( 7 times ).
#
# -- Pune is the most popular Place for EV companies.

# %%
PCS= pd.read_csv("/kaggle/input/ev-data/OperationalPC.csv")
print(PCS)
print(" ")
print(" Finding is there any Null values")
PCS.isnull().sum()
# Out:
#                 State  No. of Operational PCS
# 0   Andaman & Nicobar                       3
# 1      Andhra Pradesh                     327
# 2   Arunachal Pradesh                       9
# 3               Assam                      86
# 4               Bihar                     124
# 5          Chandigarh                      12
# 6        Chhattisgarh                     149
# 7         D&D and DNH                       1
# 8               Delhi                    1886
# 9                 Goa                     113
# 10            Gujarat                     476
# 11            Haryana                     377
# 12   Himachal Pradesh                      44
# 13  Jammu and Kashmir                      47
# 14          Jharkhand                     135
# 15          Karnataka                    1041
# 16             Kerala                     852
# 17        Lakshadweep                       1
# 18     Madhya Pradesh                     341
# ...

# %%
# Datatypes of the columns and shape of the dataset
print(PCS.dtypes)
PCS.shape
# Out:
# State                     object
# No. of Operational PCS     int64
# dtype: object
# (34, 2)

# %%
PCS.describe()
# Out:
#        No. of Operational PCS
# count               34.000000
# mean               357.235294
# std                617.579099
# min                  1.000000
# 25%                 18.750000
# 50%                129.500000
# 75%                451.250000
# max               3079.000000

# %%
# Geographical Analysis: 
# Study how the demand for electric vehicles varies across different regions in India.
# Which regions are leading in EV adoption,
# and what might be the reasons behind this trend?


PCS.sort_values(by='No. of Operational PCS', ascending=False)
# Out:
#                 State  No. of Operational PCS
# 19        Maharashtra                    3079
# 8               Delhi                    1886
# 15          Karnataka                    1041
# 16             Kerala                     852
# 28         Tamil Nadu                     643
# 31      Uttar Pradesh                     582
# 26          Rajasthan                     500
# 29          Telangana                     481
# 10            Gujarat                     476
# 11            Haryana                     377
# 18     Madhya Pradesh                     341
# 1      Andhra Pradesh                     327
# 33        West Bengal                     318
# 23             Odisha                     198
# 25             Punjab                     158
# 6        Chhattisgarh                     149
# 14          Jharkhand                     135
# 4               Bihar                     124
# 9                 Goa                     113
# ...

# %% [markdown]
# --Maharastra has the highest No.of Operational Public Charging Stations (3079), followed by Delhi with 1886 PCS and Karnataka with 1041 PCS. [regions are leading in EV adoption]
#
# -- Lakshadweep and D&D and DNH have the lowest, each with only 1 operational PCS.
#
# This above sorted data will help to identify the regions/states (Maharastra, Delhi, and Karnataka ) which have the most developed infrastructure for electric vehicle charging, which could related to higher adoption rates of electric vehicles in those areas.
#
# Finally Lakshadweep and D&D and DNH are having less demand for electric vehicles as compared to all other regions in India according to the dataset we are taken , and the possible reason behind this might be these states has only 1 Public charging station i.e., in these regions EVs are not much adopted so, Public charging stations are also less in these areas.

# %%
VC= pd.read_csv("/kaggle/input/ev-data/Vehicle Class - All.csv")
print(VC)
print(" ")
print(" Finding is there any Null values")
VC.isnull().sum()
# Out:
#                       Vehicle Class Total Registration
# 0   FOUR WHEELER (INVALID CARRIAGE)             21,346
# 1               HEAVY GOODS VEHICLE          58,70,865
# 2               HEAVY MOTOR VEHICLE           1,02,965
# 3           HEAVY PASSENGER VEHICLE           8,28,189
# 4               LIGHT GOODS VEHICLE        1,02,49,591
# 5               LIGHT MOTOR VEHICLE        6,50,61,773
# 6           LIGHT PASSENGER VEHICLE          43,43,410
# 7              MEDIUM GOODS VEHICLE           8,75,789
# 8              MEDIUM MOTOR VEHICLE           1,94,600
# 9          MEDIUM PASSENGER VEHICLE           3,25,015
# 10       OTHER THAN MENTIONED ABOVE          11,26,398
# 11                THREE WHEELER(NT)           6,79,804
# 12                 THREE WHEELER(T)        1,07,08,473
# 13   TWO WHEELER (INVALID CARRIAGE)           1,10,788
# 14                  TWO WHEELER(NT)       27,49,71,646
# 15                   TWO WHEELER(T)           1,29,181
#
# ...

# %%
VC.describe()
# Out:
#                           Vehicle Class Total Registration
# count                                16                 16
# unique                               16                 16
# top     FOUR WHEELER (INVALID CARRIAGE)             21,346
# freq                                  1                  1

# %%
print(VC.dtypes)
print(VC.shape)
# Out:
# Vehicle Class         object
# Total Registration    object
# dtype: object
# (16, 2)

# %%
# Total Registration column is in the object datatype--which can be mix of datatypes,
# so first of all, I can convert it into the string datatype and then str to int datatype
# for doing further analysis with this column.

VC['Total Registration'] = VC['Total Registration'].astype(str)

# %%
VC['Total Registration'] = VC['Total Registration'].str.replace(',', '')

# %%
VC['Total Registration'] = VC['Total Registration'].astype(int)

# %%
VC.describe()
# Out:
#        Total Registration
# count        1.600000e+01
# mean         2.347499e+07
# std          6.894523e+07
# min          2.134600e+04
# 25%          1.782452e+05
# 50%          8.519890e+05
# 75%          6.965546e+06
# max          2.749716e+08

# %%
# finding which vehicle class having more registartions and other analysis

VC.sort_values(by='Total Registration', ascending=False)
# Out:
#                       Vehicle Class  Total Registration
# 14                  TWO WHEELER(NT)           274971646
# 5               LIGHT MOTOR VEHICLE            65061773
# 12                 THREE WHEELER(T)            10708473
# 4               LIGHT GOODS VEHICLE            10249591
# 1               HEAVY GOODS VEHICLE             5870865
# 6           LIGHT PASSENGER VEHICLE             4343410
# 10       OTHER THAN MENTIONED ABOVE             1126398
# 7              MEDIUM GOODS VEHICLE              875789
# 3           HEAVY PASSENGER VEHICLE              828189
# 11                THREE WHEELER(NT)              679804
# 9          MEDIUM PASSENGER VEHICLE              325015
# 8              MEDIUM MOTOR VEHICLE              194600
# 15                   TWO WHEELER(T)              129181
# 13   TWO WHEELER (INVALID CARRIAGE)              110788
# 2               HEAVY MOTOR VEHICLE              102965
# 0   FOUR WHEELER (INVALID CARRIAGE)               21346

# %% [markdown]
# -- With this above analysis we can analyze that **TWO WHEELER(NT- Non Transport)** have the highest registration count of** 274971646** . This shows that TWO WHEELER(NT) market is the most dominant sector in the EV industry because of it is most convienient for the individual families for personal purpose.
#
# -- **LIGHT MOTOR VEHICLE 65061773** are having the second highest registration in the Electric Vehicles. Carsand similar type of vehicles are also dominating in the EV industry because of their ease of use.
#
# ​-- **FOUR WHEELER (INVALID CARRIAGE) 21346** are the lowest share in the EV industry. These vehicles are very low in registartion among all other EVs. These are basically used for people with disability and having special uses.
#
# ​-- Other than these above anlysis, we can also analyze that **Heavy motor vehicles (HMV -102965 ) and medium motor vehicles (MMV- 194600)** have comparatively lower registrations.​
#
# * By using above insights I can Recommend that, EV Makers should focus more and continue supporting the Two wheeler(NT) and Light motor vehicles as these are the most dominant vehicles in the EV sector because of easy maintanence and for personal use for people with lower cost as compared to heavy vehicles.

# %%
ev_cat= pd.read_csv("/kaggle/input/ev-data/ev_cat_01-24.csv")
print(ev_cat)
print(" ")
print(" Finding is there any Null values")
ev_cat.isnull().sum()
# Out:
#          Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 0           0                                0                    0
# 1    01/01/01                                0                    1
# 2    01/01/02                                0                    2
# 3    01/01/03                                0                    1
# 4    01/01/04                                0                    2
# ..        ...                              ...                  ...
# 279  01/12/19                                0                    0
# 280  01/12/20                                0                    0
# 281  01/12/21                                2                    0
# 282  01/12/22                                0                    0
# 283  01/12/23                                3                   16
#
#      HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 0                      0                        0                    0
# ...

# %%
# here we remove the first row in the data because it contains all 0's which is unnecessary for us.

ev_cat_new= ev_cat.drop(ev_cat.index[0])
ev_cat_new
# Out:
#          Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 1    01/01/01                                0                    1
# 2    01/01/02                                0                    2
# 3    01/01/03                                0                    1
# 4    01/01/04                                0                    2
# 5    01/01/05                                0                    0
# ..        ...                              ...                  ...
# 279  01/12/19                                0                    0
# 280  01/12/20                                0                    0
# 281  01/12/21                                2                    0
# 282  01/12/22                                0                    0
# 283  01/12/23                                3                   16
#
#      HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 1                      0                        0                    9
# ...

# %%
ev_cat_new.describe()
# Out:
#        FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# count                       283.000000           283.000000
# mean                          0.342756             2.169611
# std                           1.225834            12.068930
# min                           0.000000             0.000000
# 25%                           0.000000             0.000000
# 50%                           0.000000             0.000000
# 75%                           0.000000             1.000000
# max                          10.000000           183.000000
#
#        HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# count           283.000000               283.000000           283.000000
# mean              0.515901                28.731449            44.964664
# std               1.025695                79.088549           132.271583
# min               0.000000                 0.000000             0.000000
# ...

# %%
print(ev_cat_new.dtypes)
print(ev_cat_new.shape)
# Out:
# Date                               object
# FOUR WHEELER (INVALID CARRIAGE)     int64
# HEAVY GOODS VEHICLE                 int64
# HEAVY MOTOR VEHICLE                 int64
# HEAVY PASSENGER VEHICLE             int64
# LIGHT GOODS VEHICLE                 int64
# LIGHT MOTOR VEHICLE                 int64
# LIGHT PASSENGER VEHICLE             int64
# MEDIUM GOODS VEHICLE                int64
# MEDIUM PASSENGER VEHICLE            int64
# MEDIUM MOTOR VEHICLE                int64
# OTHER THAN MENTIONED ABOVE          int64
# THREE WHEELER(NT)                   int64
# TWO WHEELER (INVALID CARRIAGE)      int64
# THREE WHEELER(T)                    int64
# TWO WHEELER(NT)                     int64
# TWO WHEELER(T)                      int64
# dtype: object
# (283, 17)

# %%
# extracting Year from the Date Column

ev_cat_new['Year'] = pd.DatetimeIndex(ev_cat_new['Date']).year
ev_cat_new['Year']
# Out:
# 1      2001
# 2      2002
# 3      2003
# 4      2004
# 5      2005
#        ...
# 279    2019
# 280    2020
# 281    2021
# 282    2022
# 283    2023
# Name: Year, Length: 283, dtype: int32

# %%
ev_cat_new
# Out:
#          Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 1    01/01/01                                0                    1
# 2    01/01/02                                0                    2
# 3    01/01/03                                0                    1
# 4    01/01/04                                0                    2
# 5    01/01/05                                0                    0
# ..        ...                              ...                  ...
# 279  01/12/19                                0                    0
# 280  01/12/20                                0                    0
# 281  01/12/21                                2                    0
# 282  01/12/22                                0                    0
# 283  01/12/23                                3                   16
#
#      HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 1                      0                        0                    9
# ...

# %%
# grouping by year we can find the sum of the EVs category

ev_cat_new_sum = ev_cat_new.groupby('Year').sum(numeric_only=True).reset_index()
ev_cat_new_sum
# Out:
#     Year  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 0   2001                                0                    7
# 1   2002                                0                    8
# 2   2003                                0                    6
# 3   2004                                0                    8
# 4   2005                                0                    7
# 5   2006                                0                    7
# 6   2007                                0                    4
# 7   2008                                0                    8
# 8   2009                                0                    2
# 9   2010                                0                   20
# 10  2011                                0                   14
# 11  2012                                0                   21
# 12  2013                                0                   21
# 13  2014                                0                    9
# ...

# %% [markdown]
# -- maximum in all categories EVs are increased from 2001 to 2023

# %%
# sum of total vehicles over the years based on EV category

cat_sum=ev_cat_new_sum.drop('Year',axis=1).sum()
cat_sum.sort_values(ascending=False)
# Out:
# TWO WHEELER(NT)                    2308887
# THREE WHEELER(T)                   1932683
# LIGHT MOTOR VEHICLE                 180330
# LIGHT PASSENGER VEHICLE              22807
# TWO WHEELER(T)                       13459
# LIGHT GOODS VEHICLE                  12725
# HEAVY PASSENGER VEHICLE               8131
# OTHER THAN MENTIONED ABOVE            7589
# THREE WHEELER(NT)                     1498
# MEDIUM PASSENGER VEHICLE               776
# HEAVY GOODS VEHICLE                    614
# HEAVY MOTOR VEHICLE                    146
# TWO WHEELER (INVALID CARRIAGE)         126
# FOUR WHEELER (INVALID CARRIAGE)         97
# MEDIUM MOTOR VEHICLE                    49
# MEDIUM GOODS VEHICLE                    31
# dtype: int64

# %% [markdown]
# -- Form the above analysis we can say that Two wheeler(NT) has the most demand EV with 2308887 vehicles raised from 2001 to 2024
# -- second and third highest demand Electric vehicles are Three wheeler(T)- 1932683, LIGHT MOTOR VEHICLE- 180330
# -- These EVs are mostly adopted/manufactured from 2001 to 2024
#
# -- the least EV category is medium goods vehicle with number of 31 vehicles only from 2001 to 2024

# %%
yearly_sum= ev_cat_new_sum.drop('Year',axis=1).sum(axis=1)
yearly_sum
# Out:
# 0        1622
# 1        2416
# 2         848
# 3         610
# 4        1173
# 5        1622
# 6        3217
# 7       12775
# 8        7383
# 9        4628
# 10       6951
# 11       5473
# 12       2700
# 13       2380
# 14       7794
# 15      49834
# 16      87398
# 17     130257
# 18     166878
# 19     124671
# 20     331576
# 21    1025001
# 22    1532343
# 23     980398
# dtype: int64

# %%
# EV Adoption Trends:
# Analyze the adoption rate of electric vehicles over the years.
# How has the demand for EVs changed over time?

yearly_sum_with_year = pd.DataFrame({'Year': ev_cat_new_sum['Year'], 'Yearly Sum': yearly_sum})
yearly_sum_with_year
# Out:
#     Year  Yearly Sum
# 0   2001        1622
# 1   2002        2416
# 2   2003         848
# 3   2004         610
# 4   2005        1173
# 5   2006        1622
# 6   2007        3217
# 7   2008       12775
# 8   2009        7383
# 9   2010        4628
# 10  2011        6951
# 11  2012        5473
# 12  2013        2700
# 13  2014        2380
# 14  2015        7794
# 15  2016       49834
# 16  2017       87398
# 17  2018      130257
# 18  2019      166878
# 19  2020      124671
# 20  2021      331576
# 21  2022     1025001
# 22  2023     1532343
# 23  2024      980398

# %% [markdown]
# * overall the EV adoption/manufacturing is relatively incread from 2001 to 2024
# * according to the above analysis in 2023 EVs are adopted/manufactured mostly.

# %%
import matplotlib.pyplot as plt



# Plotting
plt.figure(figsize=(10,6))
plt.plot(yearly_sum_with_year['Year'], yearly_sum_with_year['Yearly Sum'], marker='o')
plt.title('EVs manufactured/adoption rate over the years')
plt.xlabel('Year')
plt.ylabel('Yearly Sum')
plt.grid(True)

plt.show()

# %%
ev_sales= pd.read_csv("/kaggle/input/ev-data/ev_sales_by_makers_and_cat_15-24.csv")
print(ev_sales)
print(" ")
print(" Finding is there any Null values")
ev_sales.isnull().sum()
# Out:
#      Cat                                            Maker  2015  2016  2017  \
# 0     3W                      "VOLVO GROUP INDIA PVT LTD"     0     0    31
# 1     3W                           3EV INDUSTRIES PVT LTD     0     0     0
# 2     2W                           3GB TECHNOLOGY PVT LTD     0     0     0
# 3     3W                           3GB TECHNOLOGY PVT LTD     0     1     1
# 4     3W                    3S INDUSTRIES PRIVATE LIMITED     0     0     0
# ...   ..                                              ...   ...   ...   ...
# 1381  2W        ZHEJIANG LUYUAN (IMPORTER: DYNAM EV TECH)     0     0     0
# 1382  2W  ZHEJIANG TIANYING  (IMPORTER: NEWTRON ELECTRIC)     0     0     0
# 1383  2W          ZHONGHUALONG (IMPORTER: POWORO PVT LTD)     0     0     0
# 1384  2W           ZHONGXING (IMPORTER:GREENO AUTOMOBILE)     0     0     0
# 1385  3W                      ZOHAN TRADERS AND BIG METRO     0     0     0
#
#       2018  2019  2020  2021  2022  2023  2024
# ...

# %%
print(ev_sales.dtypes)
print(ev_sales.shape)
# Out:
# Cat      object
# Maker    object
# 2015      int64
# 2016      int64
# 2017      int64
# 2018      int64
# 2019      int64
# 2020      int64
# 2021      int64
# 2022      int64
# 2023      int64
# 2024      int64
# dtype: object
# (1386, 12)

# %%
# finding total sales group by Maker(company)

ev_sales_sum = ev_sales.groupby([ 'Maker']).sum(numeric_only=True)
ev_sales_sum
# Out:
#                                                  2015  2016  2017  2018  2019  \
# Maker
# "VOLVO GROUP INDIA PVT LTD"                         0     0    31    12     0
# 3EV INDUSTRIES PVT LTD                              0     0     0     0     0
# 3GB TECHNOLOGY PVT LTD                              0     1     1     1     0
# 3S INDUSTRIES PRIVATE LIMITED                       0     0     0     0    51
# A B EXCAVATORS & EARTHMOVER LTD                     0     1     0     0     0
# ...                                               ...   ...   ...   ...   ...
# ZHEJIANG LUYUAN (IMPORTER: DYNAM EV TECH)           0     0     0     0     0
# ZHEJIANG TIANYING  (IMPORTER: NEWTRON ELECTRIC)     0     0     0     0     0
# ZHONGHUALONG (IMPORTER: POWORO PVT LTD)             0     0     0     0     0
# ZHONGXING (IMPORTER:GREENO AUTOMOBILE)              0     0     0     0     0
# ZOHAN TRADERS AND BIG METRO                         0     0     0     0     0
#
# ...

# %%
# Manufacturer Performance:
# Compare the performance of different EV manufacturers. 
# Which companies have the highest market share, 
# and what factors contribute to their success?

ev_sales_sum['Total Sales(15-24)']= ev_sales_sum.sum(axis=1)
ev_sales_sum.sort_values(by='Total Sales(15-24)',ascending=False)
# Out:
#                                      2015  2016  2017  2018   2019  2020  \
# Maker
# OLA ELECTRIC TECHNOLOGIES PVT LTD       0     0     0     0      0     0
# TVS MOTOR COMPANY LTD                 167   177    75    26     30   233
# ATHER ENERGY PVT LTD                    0     0     0    24   2291  3052
# HERO ELECTRIC VEHICLES PVT. LTD         1    34   234  5832  11170  8247
# BAJAJ AUTO LTD                        198   136   129   120     28  1262
# ...                                   ...   ...   ...   ...    ...   ...
# SAN MOTORS LIMITED                      0     0     1     0      0     0
# IDEAL JAWA INDIA PVT LTD                0     0     1     0      0     0
# AKSMD RECHARGEABLE VEHICLES PVT LTD     0     0     0     0      1     0
# SAKTHI VIJAY INDUSTRIES                 0     0     1     0      0     0
# SHRI RAM INDUSTRIES                     0     0     0     1      0     0
#
#                                       2021    2022    2023    2024  \
# Maker
# ...

# %% [markdown]
# * According to the above analysis we can say that **588266** no.of sales are done by **OLA ELECTRIC TECHNOLOGIES PVT LTD** which has the top performing company in EV market share among all other companies and Total sales done by this company from **2015 to 2024** is the key factor to contribute to its success.

# %%
ev_sales_sum.sum()
# Out:
# 2015                     7752
# 2016                    49249
# 2017                    87019
# 2018                   129763
# 2019                   165786
# 2020                   123770
# 2021                   328854
# 2022                  1020533
# 2023                  1529234
# 2024                   978943
# Total Sales(15-24)    4420903
# dtype: int64

# %% [markdown]
# -- EV Adoption Trends: Analyze the adoption rate of electric vehicles over the years. How has the demand for EVs changed over time?
#
# * by this also we can say that from **2015 to 2024** the adoption rate of electric vehicles are significantly increasing.The demand for EVs over time is more and in **2023 has the most adopting year for the EVs.**
